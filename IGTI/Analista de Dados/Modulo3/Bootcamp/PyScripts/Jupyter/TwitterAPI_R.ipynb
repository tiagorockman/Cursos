# %%
#instala packages
install.packages("rtweet")
#install.packages("twitterR") pacote mais antigo
# Out:
# package 'rtweet' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\jose.sousa1\AppData\Local\Temp\RtmpoD6VBu\downloaded_packages

# %%
#import library API
library(rtweet)

# %%
## install httpuv if not already
if (!requireNamespace("httpuv", quietly = TRUE)) {
  install.packages("httpuv")
}

# %%
# seta diretorio de trabalho
setwd("C:\\Users\\jose.sousa1\\Documents\\Treinamentos\\Cursos - Git Repository\\IGTI\\Modulo3\\Bootcamp\\PyScripts\\Jupyter\\TwitterData")

# %%
#autenticacao
## store api keys
apikey <- "w14sE6WOPocTI0ZCmrXMoXLK2"
apisecret_key <- "IChDWYpSXRr5HFGxFKtoSUaEysiiY3LIIKVDrR4twEpk1QSZ9Y"
accesstoken <- "1574569164-EQGkgTBJhCIRwWPUWjCGZK7pkwV8P6ZKwDz1fSA"
accesstoken_secret <- "nrppar8dsdmQT1fFcGvYgbeBHu9JvcjIZzjPEpYOuzky8"

## authenticate via web browser
token <- create_token(
  app = "ExemploIGTIJames",
  consumer_key = apikey,
  consumer_secret = apisecret_key,
  access_token = accesstoken,
  access_secret = accesstoken_secret)

# %%
#parametro para busca
screen_name <- "jairbolsonaro"
filename <- paste("TweetsByNameRawData_", screen_name, ".csv", sep="")

#buscando no twitter
tweets <- get_timeline(screen_name, n=1000, include_rts=TRUE, exclude_replies=TRUE)

#Salvando o vetor de tweets como CSV e apenas o Texto em TXT na codificação do portugues
write_as_csv(tweets, filename, fileEncoding="latin1//TRANSLTI")

##plota a serie temporal dos tweets
ts_plot(tweets, "3 hours") +
    ggplot2::theme_minimal() +
    ggplot2::theme(plot.title = ggplot2::element_text (face = "bold")) +
    ggplot2::labs (
    x = NULL, y = NULL,
        title= "Frequencia de tweets da conta 'jairbolsonaro' nos ultimos 9 dias",
        subtitle = "Contagem de tweets agregados em intervalos de 3 horas",
        caption = "\nFonte: Dados coletados do Twitter com o pacote rtweet"
    )
# Out:
# plot without title

# %%
#parametro para busca
screen_name <- "Rconstantino"
filename <- paste("TweetsByNameRawData_", screen_name, ".csv", sep="")

#buscando no twitter
tweets <- get_timeline(screen_name, n=1000, include_rts=TRUE, exclude_replies=TRUE)

#Salvando o vetor de tweets como CSV e apenas o Texto em TXT na codificação do portugues
write_as_csv(tweets, filename, fileEncoding="latin1//TRANSLTI")

##plota a serie temporal dos tweets
ts_plot(tweets, "3 hours") +
    ggplot2::theme_minimal() +
    ggplot2::theme(plot.title = ggplot2::element_text (face = "bold")) +
    ggplot2::labs (
    x = NULL, y = NULL,
        title= "Frequencia de tweets da conta 'Rconstantino' nos ultimos 9 dias",
        subtitle = "Contagem de tweets agregados em intervalos de 3 horas",
        caption = "\nFonte: Dados coletados do Twitter com o pacote rtweet"
    )
# Out:
# plot without title

# %%
#parametro para busca
screen_name <- "arthurmoledoval"
filename <- paste("TweetsByNameRawData_", screen_name, ".csv", sep="")

#buscando no twitter
tweets <- get_timeline(screen_name, n=1000, include_rts=TRUE, exclude_replies=TRUE)

#Salvando o vetor de tweets como CSV e apenas o Texto em TXT na codificação do portugues
write_as_csv(tweets, filename, fileEncoding="latin1//TRANSLTI")

##plota a serie temporal dos tweets
ts_plot(tweets, "3 hours") +
    ggplot2::theme_minimal() +
    ggplot2::theme(plot.title = ggplot2::element_text (face = "bold")) +
    ggplot2::labs (
    x = NULL, y = NULL,
        title= "Frequencia de tweets da conta 'arthurmoledoval' nos ultimos 9 dias",
        subtitle = "Contagem de tweets agregados em intervalos de 3 horas",
        caption = "\nFonte: Dados coletados do Twitter com o pacote rtweet"
    )
# Out:
# plot without title

# %%
# Out:
# [1] "TweetsByNameRawData_arthurmoledoval.csv"
